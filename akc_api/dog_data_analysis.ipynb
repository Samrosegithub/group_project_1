# %%
import requests
import json
from config import ninjas_api_key
from pprint import pprint
import pandas as pd
from scipy import stats
from scipy.stats import linregress
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')


ninjas_api_key
# Out:
# 'FMF94KnWZeyC3BCAwOVH6Q==whGgFPv3Q6qfhbOv'

# %%
# TESTING: API test call - One dog

name = "Small Munsterlander Pointer" #"Slovensky Kopov" #"German Shepherd Dog" #"Maltese" #"German Sheppard"

url = "https://api.api-ninjas.com/v1/dogs?name={}"
api_url = url.format(name)
response = requests.get(api_url, headers={'X-Api-Key': ninjas_api_key})

json_response = response.json()

print(json.dumps(json_response, indent = 4, sort_keys = True))
# Out:
# []

# %%
# TESTING: Working with 3 dogs now

dogs_list = ["German Shepherd Dog", "Maltese", "Dalmatian"]

name = dogs_list[2]

dogs_list_output = []

url = "https://api.api-ninjas.com/v1/dogs?name={}"

for dog in dogs_list:
    api_url = url.format(dog)
    response = requests.get(api_url, headers={'X-Api-Key': ninjas_api_key})
    dogs = response.json()
    print(dogs[0]["name"])
    
    # parsing out json record keys 
    dog_name = dogs[0]['name']
    image_link = dogs[0]['image_link']
    barking = dogs[0]['barking']
    coat_length = dogs[0]['coat_length']
    drooling = dogs[0]['drooling']
    energy = dogs[0]['energy']
    good_with_children = dogs[0]['good_with_children']
    good_with_other_dogs = dogs[0]['good_with_other_dogs']
    good_with_strangers = dogs[0]['good_with_strangers']
    grooming = dogs[0]['grooming']
    max_height_female = dogs[0]['max_height_female']
    max_height_male = dogs[0]['max_height_male']
    max_life_expectancy = dogs[0]['max_life_expectancy']
    max_weight_female = dogs[0]['max_weight_female']
    max_weight_male = dogs[0]['max_weight_male']
    min_height_female = dogs[0]['min_height_female']
    min_height_male = dogs[0]['min_height_male']
    min_life_expectancy = dogs[0]['min_life_expectancy']
    min_weight_female = dogs[0]['min_weight_female']
    min_weight_male = dogs[0]['min_weight_male']
    playfulness = dogs[0]['playfulness']
    protectiveness = dogs[0]['protectiveness']
    shedding = dogs[0]['shedding']
    trainability = dogs[0]['trainability']
    
    # appending dog data points into list/dictionary
    
    dogs_list_output.append({"Dog Name" : dog_name,
                             "Image Link" : image_link,
                             "Barking" : barking,
                             "Coat Length" : coat_length,
                             "Drooling" : drooling, 
                             "Energy" : energy, 
                             "Good with children" : good_with_children, 
                             "Good with other dogs" : good_with_other_dogs, 
                             "Good with strangers" : good_with_strangers, 
                             "Grooming" : grooming, 
                             "Max Height Female" : max_height_female, 
                             "Max Height Male" : max_height_male, 
                             "Max Life Expectancy" : max_life_expectancy, 
                             "Max Weight Female" : max_weight_female, 
                             "Max Weight Male" : max_weight_male,
                             "Min Height Female" : min_height_female, 
                             "Min Height Male" : min_height_male, 
                             "Min Life Expectancy" : min_life_expectancy,
                             "Min Weight Female" : min_weight_female,
                             "Min Weight Male" : min_weight_male,
                             "Playfulness" : playfulness,
                             "Protectiveness" : protectiveness,
                             "Shedding" : shedding, 
                             "Trainability" : trainability})





dogs_list_output # not a dataframe
# Out:
# German Shepherd Dog
# Maltese
# Dalmatian
# [{'Dog Name': 'German Shepherd Dog',
#   'Image Link': 'https://api-ninjas.com/images/dogs/german_shepherd_dog.jpg',
#   'Barking': 3,
#   'Coat Length': 1,
#   'Drooling': 2,
#   'Energy': 5,
#   'Good with children': 5,
#   'Good with other dogs': 3,
#   'Good with strangers': 3,
#   'Grooming': 2,
#   'Max Height Female': 26.0,
#   'Max Height Male': 26.0,
#   'Max Life Expectancy': 10.0,
#   'Max Weight Female': 70.0,
#   'Max Weight Male': 90.0,
#   'Min Height Female': 24.0,
#   'Min Height Male': 24.0,
#   'Min Life Expectancy': 7.0,
#   'Min Weight Female': 50.0,
#   'Min Weight Male': 65.0,
#   'Playfulness': 4,
#   'Protectiveness': 5,
#   'Shedding': 4,
#   'Trainability': 5},
#  {'Dog Name': 'Maltese',
#   'Image Link': 'https://api-ninjas.com/images/dogs/maltese.jpg',
#   'Barking': 3,
#   'Coat Length': 1,
#   'Drooling': 1,
#   'Energy': 3,
#   'Good with children': 3,
#   'Good with other dogs': 3,
#   'Good with strangers': 3,
#   'Grooming': 4,
#   'Max Height Female': 9.0,
#   'Max Height Male': 9.0,
#   'Max Life Expectancy': 15.0,
#   'Max Weight Female': 8.8,
#   'Max Weight Male': 8.8,
#   'Min Height Female': 7.0,
#   'Min Height Male': 7.0,
#   'Min Life Expectancy': 12.0,
#   'Min Weight Female': 6.6,
#   'Min Weight Male': 6.6,
#   'Playfulness': 3,
#   'Protectiveness': 4,
#   'Shedding': 1,
#   'Trainability': 3},
#  {'Dog Name': 'Dalmatian',
#   'Image Link': 'https://api-ninjas.com/images/dogs/dalmatian.jpg',
#   'Barking': 3,
#   'Coat Length': 1,
#   'Drooling': 2,
#   'Energy': 4,
#   'Good with children': 3,
#   'Good with other dogs': 3,
#   'Good with strangers': 4,
#   'Grooming': 2,
#   'Max Height Female': 24.0,
#   'Max Height Male': 24.0,
#   'Max Life Expectancy': 13.0,
#   'Max Weight Female': 70.0,
#   'Max Weight Male': 70.0,
#   'Min Height Female': 19.0,
#   'Min Height Male': 19.0,
#   'Min Life Expectancy': 11.0,
#   'Min Weight Female': 45.0,
#   'Min Weight Male': 45.0,
#   'Playfulness': 4,
#   'Protectiveness': 4,
#   'Shedding': 4,
#   'Trainability': 4}]

# %%
# TESTING: creating dogs dataframe with 3 dogs

dogs_df = pd.DataFrame(dogs_list_output, columns=['Dog Name', 'Image Link', 'Barking', 'Coat Length', 'Drooling', 'Energy', 'Good with children', 'Good with other dogs', 'Good with strangers', 'Grooming', 'Max Height Female', 'Max Height Male', 'Max Life Expectancy', 'Max Weight Female', 'Max Weight Male', 'Min Height Female', 'Min Height Male', 'Min Life Expectancy', 'Min Weight Female', 'Min Weight Male', 'Playfulness', 'Protectiveness', 'Shedding', 'Trainability' ])

dogs_df
dogs_df.count()
# Out:
# Dog Name                3
# Image Link              3
# Barking                 3
# Coat Length             3
# Drooling                3
# Energy                  3
# Good with children      3
# Good with other dogs    3
# Good with strangers     3
# Grooming                3
# Max Height Female       3
# Max Height Male         3
# Max Life Expectancy     3
# Max Weight Female       3
# Max Weight Male         3
# Min Height Female       3
# Min Height Male         3
# Min Life Expectancy     3
# Min Weight Female       3
# Min Weight Male         3
# Playfulness             3
# Protectiveness          3
# Shedding                3
# Trainability            3
# dtype: int64

# %%
# TESTING: Looking at the csv data

dogs_csv = pd.read_csv("../akc_data.csv")

dogs_list = dogs_csv["dog_name"]
# dogs_list

# print(dog_names[0])
dogs_csv
# Out:
#               dog_name                                        description  \
# 0        Affenpinscher  The Affen’s apish look has been described many...
# 1         Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2     Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3                Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4     Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
# ..                 ...                                                ...
# 272  Wirehaired Vizsla  WVs are close relatives of Vizslas but a disti...
# 273     Working Kelpie  The overall appearance of the Working Kelpie i...
# 274     Xoloitzcuintli  The Xoloitzcuintli (show-low-eats-queen-tlee) ...
# 275     Yakutian Laika  For centuries the Yakutian Laika was an irrepl...
# 276  Yorkshire Terrier  The Yorkshire Terrier is a compact, toy-size t...
#
#                                    temperament popularity  min_height  \
# 0          Confident, Famously Funny, Fearless        148       22.86
# 1    Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2                 Friendly, Clever, Courageous         60       58.42
# 3      Courageous, Dignified, Profoundly Loyal         47       60.96
# 4                 Affectionate, Loyal, Playful         58       58.42
# ..                                         ...        ...         ...
# 272                   Gentle, Loyal, Trainable        167       54.61
# 273                  Alert, Eager, Intelligent        NaN       48.26
# 274                         Loyal, Alert, Calm        140       25.40
# 275          Affectionate, Intelligent, Active        NaN       53.34
# 276         Affectionate, Sprightly, Tomboyish         10       17.78
#
#      max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0         29.21    3.175147    4.535924            12.0            15.0  ...
# 1         68.58   22.679619   27.215542            12.0            15.0  ...
# 2         58.42   22.679619   31.751466            11.0            14.0  ...
# 3         71.12   31.751466   58.967008            10.0            13.0  ...
# 4         63.50   34.019428   38.555351            10.0            14.0  ...
# ..          ...         ...         ...             ...             ...  ...
# 272       63.50   20.411657   29.483504            12.0            14.0  ...
# 273       63.50   12.700586   27.215542            12.0            15.0  ...
# 274       58.42    4.535924   24.947580            13.0            18.0  ...
# 275       58.42   18.143695   24.947580            10.0            12.0  ...
# 276       20.32    3.175147    3.175147            11.0            15.0  ...
#
#     grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                        0.6    2-3 Times a Week Brushing            0.6
# 1                        0.8               Daily Brushing            0.2
# 2                        0.6    2-3 Times a Week Brushing            0.4
# 3                        0.8               Daily Brushing            0.6
# 4                        0.6    2-3 Times a Week Brushing            0.6
# ..                       ...                          ...            ...
# 272                      0.2        Occasional Bath/Brush            0.6
# 273                      0.2        Occasional Bath/Brush            0.6
# 274                      0.2        Occasional Bath/Brush            0.2
# 275                      0.4              Weekly Brushing            0.6
# 276                      1.0       Specialty/Professional            0.2
#
#      shedding_category energy_level_value  energy_level_category  \
# 0             Seasonal                0.6       Regular Exercise
# 1           Infrequent                0.8              Energetic
# 2           Occasional                0.6       Regular Exercise
# 3             Seasonal                0.8              Energetic
# 4             Seasonal                0.8              Energetic
# ..                 ...                ...                    ...
# 272           Seasonal                0.8              Energetic
# 273           Seasonal                0.8              Energetic
# 274         Infrequent                0.8              Energetic
# 275           Seasonal                0.8              Energetic
# 276         Infrequent                0.6       Regular Exercise
#
#     trainability_value  trainability_category demeanor_value  \
# 0                  0.8          Easy Training            1.0
# 1                  0.2        May be Stubborn            0.2
# 2                  1.0        Eager to Please            0.8
# 3                  1.0        Eager to Please            0.6
# 4                  0.4            Independent            0.8
# ..                 ...                    ...            ...
# 272                0.6              Agreeable            0.6
# 273                0.4            Independent            0.6
# 274                0.6              Agreeable            0.6
# 275                0.2        May be Stubborn            0.4
# 276                0.2        May be Stubborn            0.8
#
#            demeanor_category
# 0                   Outgoing
# 1                 Aloof/Wary
# 2                   Friendly
# 3           Alert/Responsive
# 4                   Friendly
# ..                       ...
# 272         Alert/Responsive
# 273         Alert/Responsive
# 274         Alert/Responsive
# 275  Reserved with Strangers
# 276                 Friendly
#
# [277 rows x 21 columns]

# %%
# loop through csv to get all dog names, build dataframe


dogs_list_output = []

url = "https://api.api-ninjas.com/v1/dogs?name={}"

# Print to logger
print("Begin Retrieval of Dogs     ")
print("-----------------------------")

for dog in dogs_list:
    api_url = url.format(dog)
    response = requests.get(api_url, headers={'X-Api-Key': ninjas_api_key})
    dogs = response.json()
    
    print(dog)
    
    try:
        # parsing out json record keys 
        dog_name = dogs[0]['name']
        image_link = dogs[0]['image_link']
        barking = dogs[0]['barking']
        coat_length = dogs[0]['coat_length']
        drooling = dogs[0]['drooling']
        energy = dogs[0]['energy']
        good_with_children = dogs[0]['good_with_children']
        good_with_other_dogs = dogs[0]['good_with_other_dogs']
        good_with_strangers = dogs[0]['good_with_strangers']
        grooming = dogs[0]['grooming']
        max_height_female = dogs[0]['max_height_female']
        max_height_male = dogs[0]['max_height_male']
        max_life_expectancy = dogs[0]['max_life_expectancy']
        max_weight_female = dogs[0]['max_weight_female']
        max_weight_male = dogs[0]['max_weight_male']
        min_height_female = dogs[0]['min_height_female']
        min_height_male = dogs[0]['min_height_male']
        min_life_expectancy = dogs[0]['min_life_expectancy']
        min_weight_female = dogs[0]['min_weight_female']
        min_weight_male = dogs[0]['min_weight_male']
        playfulness = dogs[0]['playfulness']
        protectiveness = dogs[0]['protectiveness']
        shedding = dogs[0]['shedding']
        trainability = dogs[0]['trainability']

        # appending dog data points into list/dictionary

        dogs_list_output.append({"Dog Name" : dog_name,
                                 "Image Link" : image_link,
                                 "Barking" : barking,
                                 "Coat Length" : coat_length,
                                 "Drooling" : drooling, 
                                 "Energy" : energy, 
                                 "Good with children" : good_with_children, 
                                 "Good with other dogs" : good_with_other_dogs, 
                                 "Good with strangers" : good_with_strangers, 
                                 "Grooming" : grooming, 
                                 "Max Height Female" : max_height_female, 
                                 "Max Height Male" : max_height_male, 
                                 "Max Life Expectancy" : max_life_expectancy, 
                                 "Max Weight Female" : max_weight_female, 
                                 "Max Weight Male" : max_weight_male,
                                 "Min Height Female" : min_height_female, 
                                 "Min Height Male" : min_height_male, 
                                 "Min Life Expectancy" : min_life_expectancy,
                                 "Min Weight Female" : min_weight_female,
                                 "Min Weight Male" : min_weight_male,
                                 "Playfulness" : playfulness,
                                 "Protectiveness" : protectiveness,
                                 "Shedding" : shedding, 
                                 "Trainability" : trainability})


    except:
        print("Dog " + dog + " NOT FOUND ...................................SKIPPING...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# dogs_list_output # not a dataframe
# Out:
# Begin Retrieval of Dogs
# -----------------------------
# Affenpinscher
# Afghan Hound
# Airedale Terrier
# Akita
# Alaskan Malamute
# American Bulldog
# American English Coonhound
# American Eskimo Dog
# American Foxhound
# American Hairless Terrier
# American Leopard Hound
# American Staffordshire Terrier
# American Water Spaniel
# Anatolian Shepherd Dog
# Appenzeller Sennenhund
# Dog Appenzeller Sennenhund NOT FOUND ...................................SKIPPING...
# Australian Cattle Dog
# Australian Kelpie
# Australian Shepherd
# Australian Stumpy Tail Cattle Dog
# Australian Terrier
# Azawakh
# Barbet
# Basenji
# Basset Fauve de Bretagne
# Basset Hound
# Bavarian Mountain Scent Hound
# Beagle
# Bearded Collie
# Beauceron
# Bedlington Terrier
# Belgian Laekenois
# Belgian Malinois
# Belgian Sheepdog
# Belgian Tervuren
# Dog Belgian Tervuren NOT FOUND ...................................SKIPPING...
# Bergamasco Sheepdog
# Dog Bergamasco Sheepdog NOT FOUND ...................................SKIPPING...
# Berger Picard
# Bernese Mountain Dog
# Bichon Frise
# Biewer Terrier
# Black and Tan Coonhound
# Black Russian Terrier
# Bloodhound
# Bluetick Coonhound
# Boerboel
# Bohemian Shepherd
# Bolognese
# Border Collie
# Border Terrier
# Borzoi
# Boston Terrier
# Bouvier des Flandres
# Boxer
# Boykin Spaniel
# Bracco Italiano
# Braque du Bourbonnais
# Braque Francais Pyrenean
# Briard
# Brittany
# Dog Brittany NOT FOUND ...................................SKIPPING...
# Broholmer
# Dog Broholmer NOT FOUND ...................................SKIPPING...
# Brussels Griffon
# Bull Terrier
# Bulldog
# Bullmastiff
# Cairn Terrier
# Canaan Dog
# Cane Corso
# Cardigan Welsh Corgi
# Carolina Dog
# Catahoula Leopard Dog
# Caucasian Shepherd Dog
# Cavalier King Charles Spaniel
# Central Asian Shepherd Dog
# Cesky Terrier
# Chesapeake Bay Retriever
# Chihuahua
# Chinese Crested
# Chinese Shar-Pei
# Chinook
# Chow Chow
# Dog Chow Chow NOT FOUND ...................................SKIPPING...
# Cirneco dell’Etna
# Clumber Spaniel
# Cocker Spaniel
# Collie
# Coton de Tulear
# Croatian Sheepdog
# Curly-Coated Retriever
# Czechoslovakian Vlcak
# Dachshund
# Dalmatian
# Dandie Dinmont Terrier
# Danish-Swedish Farmdog
# Deutscher Wachtelhund
# Doberman Pinscher
# Dogo Argentino
# Dogue de Bordeaux
# Drentsche Patrijshond
# Drever
# Dutch Shepherd
# English Cocker Spaniel
# English Foxhound
# English Setter
# English Springer Spaniel
# English Toy Spaniel
# Entlebucher Mountain Dog
# Estrela Mountain Dog
# Eurasier
# Field Spaniel
# Finnish Lapphund
# Finnish Spitz
# Flat-Coated Retriever
# French Bulldog
# French Spaniel
# Dog French Spaniel NOT FOUND ...................................SKIPPING...
# German Longhaired Pointer
# German Pinscher
# German Shepherd Dog
# German Shorthaired Pointer
# German Spitz
# German Wirehaired Pointer
# Giant Schnauzer
# Glen of Imaal Terrier
# Golden Retriever
# Gordon Setter
# Grand Basset Griffon Vendéen
# Great Dane
# Great Pyrenees
# Greater Swiss Mountain Dog
# Greyhound
# Hamiltonstovare
# Hanoverian Scenthound
# Harrier
# Havanese
# Hokkaido
# Hovawart
# Ibizan Hound
# Icelandic Sheepdog
# Irish Red and White Setter
# Irish Setter
# Irish Terrier
# Irish Water Spaniel
# Irish Wolfhound
# Italian Greyhound
# Dog Italian Greyhound NOT FOUND ...................................SKIPPING...
# Jagdterrier
# Dog Jagdterrier NOT FOUND ...................................SKIPPING...
# Japanese Chin
# Japanese Spitz
# Jindo
# Kai Ken
# Karelian Bear Dog
# Keeshond
# Kerry Blue Terrier
# Kishu Ken
# Komondor
# Kromfohrlander
# Kuvasz
# Labrador Retriever
# Lagotto Romagnolo
# Lakeland Terrier
# Lancashire Heeler
# Lapponian Herder
# Leonberger
# Lhasa Apso
# Löwchen
# Maltese
# Manchester Terrier (Standard)
# Manchester Terrier (Toy)
# Mastiff
# Miniature American Shepherd
# Miniature Bull Terrier
# Miniature Pinscher
# Miniature Schnauzer
# Mountain Cur
# Mudi
# Neapolitan Mastiff
# Nederlandse Kooikerhondje
# Newfoundland
# Norfolk Terrier
# Norrbottenspets
# Norwegian Buhund
# Dog Norwegian Buhund NOT FOUND ...................................SKIPPING...
# Norwegian Elkhound
# Dog Norwegian Elkhound NOT FOUND ...................................SKIPPING...
# Norwegian Lundehund
# Norwich Terrier
# Nova Scotia Duck Tolling Retriever
# Old English Sheepdog
# Otterhound
# Papillon
# Parson Russell Terrier
# Pekingese
# Pembroke Welsh Corgi
# Perro de Presa Canario
# Peruvian Inca Orchid
# Petit Basset Griffon Vendéen
# Pharaoh Hound
# Plott Hound
# Pointer
# Polish Lowland Sheepdog
# Pomeranian
# Poodle (Miniature)
# Poodle (Standard)
# Poodle (Toy)
# Porcelaine
# Dog Porcelaine NOT FOUND ...................................SKIPPING...
# Portuguese Podengo
# Portuguese Podengo Pequeno
# Portuguese Pointer
# Portuguese Sheepdog
# Portuguese Water Dog
# Pudelpointer
# Pug
# Puli
# Pumi
# Pyrenean Mastiff
# Pyrenean Shepherd
# Rafeiro do Alentejo
# Rat Terrier
# Redbone Coonhound
# Rhodesian Ridgeback
# Romanian Mioritic Shepherd Dog
# Rottweiler
# Russell Terrier
# Dog Russell Terrier NOT FOUND ...................................SKIPPING...
# Russian Toy
# Dog Russian Toy NOT FOUND ...................................SKIPPING...
# Russian Tsvetnaya Bolonka
# Saint Bernard
# Saluki
# Samoyed
# Schapendoes
# Schipperke
# Scottish Deerhound
# Scottish Terrier
# Sealyham Terrier
# Segugio Italiano
# Shetland Sheepdog
# Shiba Inu
# Shih Tzu
# Shikoku
# Siberian Husky
# Silky Terrier
# Skye Terrier
# Sloughi
# Slovakian Wirehaired Pointer
# Slovensky Cuvac
# Slovensky Kopov
# Small Munsterlander Pointer
# Dog Small Munsterlander Pointer NOT FOUND ...................................SKIPPING...
# Smooth Fox Terrier
# Soft Coated Wheaten Terrier
# Spanish Mastiff
# Spanish Water Dog
# Spinone Italiano
# Stabyhoun
# Staffordshire Bull Terrier
# Standard Schnauzer
# Sussex Spaniel
# Swedish Lapphund
# Swedish Vallhund
# Taiwan Dog
# Dog Taiwan Dog NOT FOUND ...................................SKIPPING...
# Teddy Roosevelt Terrier
# Thai Ridgeback
# Tibetan Mastiff
# Tibetan Spaniel
# Tibetan Terrier
# Tornjak
# Tosa
# Toy Fox Terrier
# Dog Toy Fox Terrier NOT FOUND ...................................SKIPPING...
# Transylvanian Hound
# Treeing Tennessee Brindle
# Treeing Walker Coonhound
# Vizsla
# Weimaraner
# Welsh Springer Spaniel
# Welsh Terrier
# West Highland White Terrier
# Wetterhoun
# Whippet
# Wire Fox Terrier
# Wirehaired Pointing Griffon
# Wirehaired Vizsla
# Working Kelpie
# Xoloitzcuintli
# Yakutian Laika
# Yorkshire Terrier
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# creating dogs full dataframe

dogs_df = pd.DataFrame(dogs_list_output, columns=['Dog Name', 'Image Link', 'Barking', 'Coat Length', 'Drooling', 'Energy', 'Good with children', 'Good with other dogs', 'Good with strangers', 'Grooming', 'Max Height Female', 'Max Height Male', 'Max Life Expectancy', 'Max Weight Female', 'Max Weight Male', 'Min Height Female', 'Min Height Male', 'Min Life Expectancy', 'Min Weight Female', 'Min Weight Male', 'Playfulness', 'Protectiveness', 'Shedding', 'Trainability' ])


# cleaning the data

#dog_df
print(dogs_df.count())

# sample duplicated record
# dog_df_dups_df = dog_df.loc[dog_df["Dog Name"] == "Bullmastiff"]
# dog_df_dups_df

dogs_df["Dog Name"].duplicated()
# print(dogs_df.duplicated())
dogs_df["Dog Name"].duplicated().sum() #5
# Out:
# Dog Name                260
# Image Link              260
# Barking                 260
# Coat Length             260
# Drooling                260
# Energy                  260
# Good with children      260
# Good with other dogs    260
# Good with strangers     260
# Grooming                260
# Max Height Female       260
# Max Height Male         260
# Max Life Expectancy     260
# Max Weight Female       260
# Max Weight Male         260
# Min Height Female       260
# Min Height Male         260
# Min Life Expectancy     260
# Min Weight Female       260
# Min Weight Male         260
# Playfulness             260
# Protectiveness          260
# Shedding                260
# Trainability            260
# dtype: int64
# 4

# %%
# drop duplicates

dog_df = dogs_df.drop_duplicates()
dog_df.count()

# sample duplicated record no more
# dog_df_dups_df = dog_df.loc[dog_df["Dog Name"] == "Bullmastiff"]
# dog_df_dups_df
# Out:
# Dog Name                256
# Image Link              256
# Barking                 256
# Coat Length             256
# Drooling                256
# Energy                  256
# Good with children      256
# Good with other dogs    256
# Good with strangers     256
# Grooming                256
# Max Height Female       256
# Max Height Male         256
# Max Life Expectancy     256
# Max Weight Female       256
# Max Weight Male         256
# Min Height Female       256
# Min Height Male         256
# Min Life Expectancy     256
# Min Weight Female       256
# Min Weight Male         256
# Playfulness             256
# Protectiveness          256
# Shedding                256
# Trainability            256
# dtype: int64

# %%
dog_df["Avg Max Weight"] = (dog_df['Max Weight Male'] + dog_df['Max Weight Female'])/2
dog_df["Avg Max Height"] = (dog_df['Max Height Male'] + dog_df['Max Height Female'])/2
dog_df["Avg Min Weight"] = (dog_df['Min Weight Male'] + dog_df['Min Weight Female'])/2
dog_df["Avg Min Height"] = (dog_df['Min Height Male'] + dog_df['Min Height Female'])/2



dog_df.head()
# Out:
#            Dog Name                                         Image Link  \
# 0     Affenpinscher  https://api-ninjas.com/images/dogs/affenpinsch...
# 1      Afghan Hound  https://api-ninjas.com/images/dogs/afghan_houn...
# 2  Airedale Terrier  https://api-ninjas.com/images/dogs/airedale_te...
# 3             Akita       https://api-ninjas.com/images/dogs/akita.jpg
# 4  Alaskan Malamute  https://api-ninjas.com/images/dogs/alaskan_mal...
#
#    Barking  Coat Length  Drooling  Energy  Good with children  \
# 0        3            2         1       3                   3
# 1        3            1         1       4                   3
# 2        3            2         1       3                   3
# 3        2            1         1       4                   3
# 4        3            1         1       4                   3
#
#    Good with other dogs  Good with strangers  Grooming  ...  \
# 0                     3                    5         3  ...
# 1                     3                    3         4  ...
# 2                     3                    3         3  ...
# 3                     1                    2         3  ...
# 4                     3                    3         3  ...
#
#    Min Weight Female  Min Weight Male  Playfulness  Protectiveness  Shedding  \
# 0                7.0              7.0            3               3         3
# 1               50.0             50.0            3               3         1
# 2               50.0             50.0            3               5         1
# 3               70.0            100.0            3               5         3
# 4               75.0             85.0            3               4         3
#
#    Trainability  Avg Max Weight  Avg Max Height  Avg Min Weight  \
# 0             3            10.0            11.5             7.0
# 1             1            60.0            27.0            50.0
# 2             3            70.0            23.0            50.0
# 3             3           115.0            28.0            85.0
# 4             5            80.0            25.0            80.0
#
#    Avg Min Height
# 0             9.0
# 1            25.0
# 2            23.0
# 3            26.0
# 4            25.0
#
# [5 rows x 28 columns]

# %%
## Define a function to categorize dogs based on weight
def categorize_dog(value):
	if value <= 22:
		return "1-Small"
	elif (value > 22) & (value <= 59):
		return "2-Medium"
	elif (value >59) & (value <= 99):
		return "3-Large"
	elif value >99:
		return "4-X-large"

## Apply this new function using the pandas.map() function
dog_df["Weight Category"] = dog_df["Avg Max Weight"].map(categorize_dog)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

dog_df
# Out:
#                                Dog Name  \
# 0                         Affenpinscher
# 1                          Afghan Hound
# 2                      Airedale Terrier
# 3                                 Akita
# 4                      Alaskan Malamute
# 5                      American Bulldog
# 6            American English Coonhound
# 7                   American Eskimo Dog
# 8                     American Foxhound
# 9             American Hairless Terrier
# 10               American Leopard Hound
# 11       American Staffordshire Terrier
# 12               American Water Spaniel
# 13               Anatolian Shepherd Dog
# 14                Australian Cattle Dog
# 15                    Australian Kelpie
# 16                  Australian Shepherd
# 17    Australian Stumpy Tail Cattle Dog
# 18                   Australian Terrier
# 19                              Azawakh
# 20                               Barbet
# 21                              Basenji
# 22             Basset Fauve de Bretagne
# 23                         Basset Hound
# 24        Bavarian Mountain Scent Hound
# 25                               Beagle
# 26                       Bearded Collie
# 27                            Beauceron
# 28                   Bedlington Terrier
# 29                    Belgian Laekenois
# 30                     Belgian Malinois
# 31                     Belgian Sheepdog
# 32                        Berger Picard
# 33                 Bernese Mountain Dog
# 34                         Bichon Frise
# 35                       Biewer Terrier
# 36              Black and Tan Coonhound
# 37                Black Russian Terrier
# 38                           Bloodhound
# 39                   Bluetick Coonhound
# 40                             Boerboel
# 41                    Bohemian Shepherd
# 42                            Bolognese
# 43                        Border Collie
# 44                       Border Terrier
# 45                               Borzoi
# 46                       Boston Terrier
# 47                 Bouvier des Flandres
# 48                                Boxer
# 49                       Boykin Spaniel
# 50                      Bracco Italiano
# 51                Braque du Bourbonnais
# 52             Braque Francais Pyrenean
# 53                               Briard
# 54                     Brussels Griffon
# 55                         Bull Terrier
# 57                          Bullmastiff
# 58                        Cairn Terrier
# 59                           Canaan Dog
# 60                           Cane Corso
# 61                 Cardigan Welsh Corgi
# 62                         Carolina Dog
# 63                Catahoula Leopard Dog
# 64               Caucasian Shepherd Dog
# 65        Cavalier King Charles Spaniel
# 66           Central Asian Shepherd Dog
# 67                        Cesky Terrier
# 68             Chesapeake Bay Retriever
# 69                            Chihuahua
# 70                      Chinese Crested
# 71                     Chinese Shar-Pei
# 72                              Chinook
# 73                    Cirneco dell’Etna
# 74                      Clumber Spaniel
# 75                       Cocker Spaniel
# 77                      Coton de Tulear
# 78                    Croatian Sheepdog
# 79               Curly-Coated Retriever
# 80                Czechoslovakian Vlcak
# 81                            Dachshund
# 82                            Dalmatian
# 83               Dandie Dinmont Terrier
# 84               Danish-Swedish Farmdog
# 85                Deutscher Wachtelhund
# 86                    Doberman Pinscher
# 87                       Dogo Argentino
# 88                    Dogue de Bordeaux
# 89                Drentsche Patrijshond
# 90                               Drever
# 91                       Dutch Shepherd
# 92               English Cocker Spaniel
# 93                     English Foxhound
# 94                       English Setter
# 95             English Springer Spaniel
# 96                  English Toy Spaniel
# 97             Entlebucher Mountain Dog
# 98                 Estrela Mountain Dog
# 99                             Eurasier
# 100                       Field Spaniel
# 101                    Finnish Lapphund
# 102                       Finnish Spitz
# 103               Flat-Coated Retriever
# 104                      French Bulldog
# 105           German Longhaired Pointer
# 106                     German Pinscher
# 107                 German Shepherd Dog
# 108          German Shorthaired Pointer
# 109                        German Spitz
# 110           German Wirehaired Pointer
# 111                     Giant Schnauzer
# 112               Glen of Imaal Terrier
# 113                    Golden Retriever
# 114                       Gordon Setter
# 115        Grand Basset Griffon Vendéen
# 116                          Great Dane
# 117                      Great Pyrenees
# 118          Greater Swiss Mountain Dog
# 119                           Greyhound
# 120                     Hamiltonstovare
# 121               Hanoverian Scenthound
# 122                             Harrier
# 123                            Havanese
# 124                            Hokkaido
# 125                            Hovawart
# 126                        Ibizan Hound
# 127                  Icelandic Sheepdog
# 128          Irish Red and White Setter
# 129                        Irish Setter
# 130                       Irish Terrier
# 131                 Irish Water Spaniel
# 132                     Irish Wolfhound
# 133                       Japanese Chin
# 134                      Japanese Spitz
# 135                               Jindo
# 136                             Kai Ken
# 137                   Karelian Bear Dog
# 138                            Keeshond
# 139                  Kerry Blue Terrier
# 140                           Kishu Ken
# 141                            Komondor
# 142                      Kromfohrlander
# 143                              Kuvasz
# 144                  Labrador Retriever
# 145                   Lagotto Romagnolo
# 146                    Lakeland Terrier
# 147                   Lancashire Heeler
# 148                    Lapponian Herder
# 149                          Leonberger
# 150                          Lhasa Apso
# 151                             Löwchen
# 152                             Maltese
# 153       Manchester Terrier (Standard)
# 154            Manchester Terrier (Toy)
# 156         Miniature American Shepherd
# 157              Miniature Bull Terrier
# 158                  Miniature Pinscher
# 159                 Miniature Schnauzer
# 160                        Mountain Cur
# 161                                Mudi
# 162                  Neapolitan Mastiff
# 163           Nederlandse Kooikerhondje
# 164                        Newfoundland
# 165                     Norfolk Terrier
# 166                     Norrbottenspets
# 167                 Norwegian Lundehund
# 168                     Norwich Terrier
# 169  Nova Scotia Duck Tolling Retriever
# 170                Old English Sheepdog
# 171                          Otterhound
# 172                            Papillon
# 173              Parson Russell Terrier
# 174                           Pekingese
# 175                Pembroke Welsh Corgi
# 176              Perro de Presa Canario
# 177                Peruvian Inca Orchid
# 178        Petit Basset Griffon Vendéen
# 179                       Pharaoh Hound
# 180                         Plott Hound
# 182             Polish Lowland Sheepdog
# 183                          Pomeranian
# 184                  Poodle (Miniature)
# 185                   Poodle (Standard)
# 186                        Poodle (Toy)
# 187                  Portuguese Podengo
# 188          Portuguese Podengo Pequeno
# 189                  Portuguese Pointer
# 190                 Portuguese Sheepdog
# 191                Portuguese Water Dog
# 192                        Pudelpointer
# 193                                 Pug
# 194                                Puli
# 195                                Pumi
# 196                    Pyrenean Mastiff
# 197                   Pyrenean Shepherd
# 198                 Rafeiro do Alentejo
# 199                         Rat Terrier
# 200                   Redbone Coonhound
# 201                 Rhodesian Ridgeback
# 202      Romanian Mioritic Shepherd Dog
# 203                          Rottweiler
# 204           Russian Tsvetnaya Bolonka
# 205                       Saint Bernard
# 206                              Saluki
# 207                             Samoyed
# 208                         Schapendoes
# 209                          Schipperke
# 210                  Scottish Deerhound
# 211                    Scottish Terrier
# 212                    Sealyham Terrier
# 213                    Segugio Italiano
# 214                   Shetland Sheepdog
# 215                           Shiba Inu
# 216                            Shih Tzu
# 217                             Shikoku
# 218                      Siberian Husky
# 219                       Silky Terrier
# 220                        Skye Terrier
# 221                             Sloughi
# 222        Slovakian Wirehaired Pointer
# 223                     Slovensky Cuvac
# 224                     Slovensky Kopov
# 225                  Smooth Fox Terrier
# 226         Soft Coated Wheaten Terrier
# 227                     Spanish Mastiff
# 228                   Spanish Water Dog
# 229                    Spinone Italiano
# 230                           Stabyhoun
# 231          Staffordshire Bull Terrier
# 232                  Standard Schnauzer
# 233                      Sussex Spaniel
# 234                    Swedish Lapphund
# 235                    Swedish Vallhund
# 236             Teddy Roosevelt Terrier
# 237                      Thai Ridgeback
# 238                     Tibetan Mastiff
# 239                     Tibetan Spaniel
# 240                     Tibetan Terrier
# 241                             Tornjak
# 242                                Tosa
# 243                 Transylvanian Hound
# 244           Treeing Tennessee Brindle
# 245            Treeing Walker Coonhound
# 233  https://api-ninjas.com/images/dogs/sussex_span...        3            1
# 234  https://api-ninjas.com/images/dogs/swedish_lap...        4            1
# 235  https://api-ninjas.com/images/dogs/swedish_val...        3            1
# 236  https://api-ninjas.com/images/dogs/teddy_roose...        4            1
# 237  https://api-ninjas.com/images/dogs/thai_ridgeb...        3            1
# 238  https://api-ninjas.com/images/dogs/tibetan_mas...        3            1
# 239  https://api-ninjas.com/images/dogs/tibetan_spa...        3            1
# 240  https://api-ninjas.com/images/dogs/tibetan_ter...        3            1
# 241     https://api-ninjas.com/images/dogs/tornjak.jpg        3            1
# 242        https://api-ninjas.com/images/dogs/tosa.jpg        3            1
# 243  https://api-ninjas.com/images/dogs/transylvani...        4            1
# 244  https://api-ninjas.com/images/dogs/treeing_ten...        5            1
# 245  https://api-ninjas.com/images/dogs/treeing_wal...        4            1
# 246      https://api-ninjas.com/images/dogs/vizsla.jpg        3            1
# 247  https://api-ninjas.com/images/dogs/weimaraner.jpg        3            1
# 248  https://api-ninjas.com/images/dogs/welsh_sprin...        3            1
# 249  https://api-ninjas.com/images/dogs/welsh_terri...        4            1
# 250  https://api-ninjas.com/images/dogs/west_highla...        5            1
# 251  https://api-ninjas.com/images/dogs/wetterhoun.jpg        0            1
# 252     https://api-ninjas.com/images/dogs/whippet.jpg        1            1
# 253  https://api-ninjas.com/images/dogs/wire_fox_te...        4            1
# 254  https://api-ninjas.com/images/dogs/wirehaired_...        3            1
# 255  https://api-ninjas.com/images/dogs/wirehaired_...        3            1
# 256  https://api-ninjas.com/images/dogs/working_kel...        3            1
# 257  https://api-ninjas.com/images/dogs/xoloitzcuin...        3            1
# 258  https://api-ninjas.com/images/dogs/yakutian_la...        4            1
# 259  https://api-ninjas.com/images/dogs/yorkshire_t...        4            1
#
#      Drooling  Energy  Good with children  Good with other dogs  \
# 0           1       3                   3                     3
# 1           1       4                   3                     3
# 2           1       3                   3                     3
# 3           1       4                   3                     1
# 4           1       4                   3                     3
# 5           0       0                   3                     3
# 6           1       4                   3                     5
# 7           1       4                   5                     3
# 8           1       4                   5                     5
# 9           1       3                   5                     3
# 10          1       4                   5                     3
# 11          1       3                   3                     3
# 12          1       3                   3                     3
# 13          1       3                   3                     3
# 14          1       5                   3                     3
# 15          1       5                   3                     3
# 16          1       5                   5                     3
# 17          1       5                   3                     1
# 18          1       4                   5                     3
# 19          1       3                   3                     3
# 20          1       3                   5                     5
# 21          1       4                   3                     3
# 22          1       4                   5                     4
# 23          4       2                   5                     5
# 24          2       4                   3                     3
# 25          1       4                   5                     5
# 26          1       4                   5                     5
# 27          1       5                   3                     3
# 28          1       4                   3                     3
# 29          1       4                   3                     3
# 30          1       4                   3                     3
# 31          1       4                   3                     3
# 32          1       4                   3                     3
# 33          3       4                   5                     5
# 34          1       4                   5                     5
# 35          1       3                   3                     5
# 36          3       3                   5                     5
# 37          3       4                   3                     3
# 38          5       3                   3                     3
# 39          2       4                   3                     5
# 40          3       3                   4                     2
# 41          2       3                   5                     3
# 42          1       4                   3                     3
# 43          1       5                   3                     3
# 44          1       3                   5                     3
# 198         3             5          132.00           29.00           77.00
# 199         3             5           25.00           13.00           10.00
# 200         3             3           70.00           27.00           45.00
# 201         3             4           77.50           27.00           77.50
# 202         2             3          130.00           29.00          100.00
# 203         3             5          117.50           27.00           87.50
# 204         1             4           11.00           10.00            4.50
# 205         3             3          160.00           30.00          130.00
# 206         2             3           65.00           28.00           40.00
# 207         3             4           57.50           23.50           40.00
# 208         2             5           55.00           20.00           26.00
# 209         3             4           16.00           13.00           10.00
# 210         3             3          102.50           32.00           80.00
# 211         2             3           21.50           10.00           18.50
# 212         3             4           23.00           10.50           21.50
# 213         3             3           60.00           23.00           40.00
# 214         3             5           25.00           16.00           15.00
# 215         3             2           20.00           16.50           20.00
# 216         1             4           16.00           10.50            9.00
# 217         3             3           55.00           22.00           35.00
# 218         4             3           55.00           23.50           40.00
# 219         2             4           10.00           10.00            8.00
# 220         3             3           40.00           10.00           30.00
# 221         3             3           50.00           29.00           35.00
# 222         2             5           65.00           26.50           50.00
# 223         4             3           97.00           27.50           68.00
# 224         3             4           44.00           20.00           33.00
# 225         3             3           17.50           15.50           16.50
# 226         1             3           37.50           19.00           32.50
# 227         3             3          200.00           35.00          140.00
# 228         1             4           44.50           19.75           35.50
# 229         3             4           80.50           27.00           69.50
# 230         3             5           60.00           21.00           40.00
# 231         2             5           36.00           16.00           26.00
# 232         1             5           47.50           19.50           32.50
# 233         3             4           45.00           15.00           35.00
# 234         3             5           45.00           20.00           30.00
# 235         4             4           35.00           13.75           20.00
# 236         3             4           25.00           15.00            8.00
# 237         3             4           75.00           24.00           35.00
# 238         4             3          135.00           29.00           80.00
# 239         3             3           15.00           10.00            9.00
# 240         3             3           31.00           17.00           18.00
# 241         4             3          110.00           28.00           62.00
# 242         2             3          200.00           23.50          100.00
# 243         3             4           77.00           26.00           66.00
# 244         2             3           50.00           24.00           30.00
# 245         3             5           70.00           27.00           50.00
# 246         3             5           57.50           24.00           49.50
# 247         3             5           82.50           27.00           62.50
# 248         3             5           52.50           19.00           37.50
# 249         2             4           22.00           15.00           20.00
# 250         3             3           20.00           11.00           15.00
# 251         0             0           75.00           23.00           50.00
# 252         2             3           40.00           22.00           25.00
# 253         2             4           17.50           15.50           16.50
# 254         3             5           60.00           24.00           42.50
# 255         3             5           60.00           25.00           50.00
# 256         3             5           60.00           25.00           28.00
# 257         1             4           60.00           25.00           28.00
# 258         4             3           55.00           23.00           40.00
# 259         1             4            7.00            8.00            7.00
#
#      Avg Min Height Weight Category
# 0              9.00         1-Small
# 1             25.00         3-Large
# 2             23.00         3-Large
# 3             26.00       4-X-large
# 4             25.00         3-Large
# 5             20.00         3-Large
# 6             24.00         3-Large
# 7             24.00         3-Large
# 8             22.00         3-Large
# 9             12.00         1-Small
# 10            21.00         3-Large
# 11            18.00         3-Large
# 12            15.00        2-Medium
# 13            29.00       4-X-large
# 14            18.00        2-Medium
# 15            17.00        2-Medium
# 16            20.00         3-Large
# 17            18.00        2-Medium
# 18            10.00         1-Small
# 19            25.00        2-Medium
# 20            19.00         3-Large
# 21            17.00        2-Medium
# 22            12.50        2-Medium
# 23            11.50         3-Large
# 24            17.00         3-Large
# 25            13.50        2-Medium
# 26            21.00        2-Medium
# 27            25.50       4-X-large
# 28            15.00        2-Medium
# 29            24.00         3-Large
# 30            24.00         3-Large
# 31            24.00         3-Large
# 32            23.50         3-Large
# 33            25.00       4-X-large
# 34             9.50         1-Small
# 35             7.00         1-Small
# 36            25.00       4-X-large
# 37            27.00       4-X-large
# 38            25.00       4-X-large
# 39            22.00         3-Large
# 40            24.00       4-X-large
# 41            20.50        2-Medium
# 42            10.00         1-Small
# 43            19.00        2-Medium
# 44            12.00         1-Small
# 45            28.50         3-Large
# 46            15.00        2-Medium
# 47            24.50       4-X-large
# 48            23.00         3-Large
# 49            15.50        2-Medium
# 50            21.00         3-Large
# 51            19.00        2-Medium
# 52            18.50        2-Medium
# 53            23.00       4-X-large
# 54             7.00         1-Small
# 55            21.00         3-Large
# 57            25.00       4-X-large
# 58            10.00         1-Small
# 59            20.00        2-Medium
# 60            25.00       4-X-large
# 61            10.50        2-Medium
# 62            17.75        2-Medium
# 63            22.00         3-Large
# 64            23.00       4-X-large
# 65            12.00         1-Small
# 66            25.00       4-X-large
# 67            10.00        2-Medium
# 68            23.00         3-Large
# 69             5.00         1-Small
# 70            11.00         1-Small
# 71            18.00         3-Large
# 72            24.00         3-Large
# 73            18.00        2-Medium
# 74            18.00         3-Large
# 75            14.50        2-Medium
# 77            10.00         1-Small
# 78            16.00        2-Medium
# 79            25.00         3-Large
# 80            23.50         3-Large
# 81             8.00        2-Medium
# 82            19.00         3-Large
# 83             8.00        2-Medium
# 84            12.50         1-Small
# 85            18.00        2-Medium
# 86            26.00         3-Large
# 87            24.00       4-X-large
# 88            23.27       4-X-large
# 89            21.00         3-Large
# 90            12.00        2-Medium
# 91            21.50         3-Large
# 92            16.00        2-Medium
# 93            24.00         3-Large
# 94            25.00         3-Large
# 95            20.00        2-Medium
# 96             9.00         1-Small
# 97            17.00         3-Large
# 98            24.50       4-X-large
# 99            19.00         3-Large
# 100           18.00        2-Medium
# 101           18.00        2-Medium
# 102           17.50        2-Medium
# 103           23.00         3-Large
# 104           11.00        2-Medium
# 105           22.00         3-Large
# 106           17.00        2-Medium
# 107           24.00         3-Large
# 108           23.00         3-Large
# 109           12.00        2-Medium
# 110           24.00         3-Large
# 111           25.50         3-Large
# 112           12.50        2-Medium
# 113           23.00         3-Large
# 114           24.00         3-Large
# 115           15.50        2-Medium
# 116           30.00       4-X-large
# 117           27.00       4-X-large
# 118           25.50       4-X-large
# 119           28.00         3-Large
# 120           19.00         3-Large
# 121           19.00         3-Large
# 122           19.00         3-Large
# 123            8.50         1-Small
# 124           18.00         3-Large
# 125           23.00         3-Large
# 126           23.50        2-Medium
# 127           18.00        2-Medium
# 128           24.50        2-Medium
# 129           27.00         3-Large
# 130           18.00        2-Medium
# 131           22.00         3-Large
# 132           32.00       4-X-large
# 133            8.00         1-Small
# 134           12.00        2-Medium
# 135           18.00        2-Medium
# 136           15.50        2-Medium
# 137           19.00        2-Medium
# 138           18.00        2-Medium
# 139           18.00        2-Medium
# 140           17.00         3-Large
# 141           26.50       4-X-large
# 142           15.00        2-Medium
# 143           28.00       4-X-large
# 144           22.50         3-Large
# 145           17.00        2-Medium
# 146           14.50         1-Small
# 147           10.00         1-Small
# 148           18.00         3-Large
# 149           28.00       4-X-large
# 150           10.00         1-Small
# 151           12.00         1-Small
# 152            7.00         1-Small
# 153           15.00         1-Small
# 154           10.00         1-Small
# 156           14.00        2-Medium
# 157           10.00        2-Medium
# 158           10.00         1-Small
# 159           12.00         1-Small
# 160           16.00         3-Large
# 161           15.00        2-Medium
# 162           26.00       4-X-large
# 163           25.50        2-Medium
# 164           28.00       4-X-large
# 165            9.00         1-Small
# 166           16.50        2-Medium
# 167           13.00        2-Medium
# 168           10.00         1-Small
# 169           18.00        2-Medium
# 170           21.00       4-X-large
# 171           27.00         3-Large
# 172            8.00         1-Small
# 173           14.00         1-Small
# 174            6.00         1-Small
# 175           10.00        2-Medium
# 176           22.00       4-X-large
# 177           20.00        2-Medium
# 178           13.00        2-Medium
# 179           23.00        2-Medium
# 180           20.00        2-Medium
# 182           18.00        2-Medium
# 183            6.00         1-Small
# 184           10.00         1-Small
# 185           15.00         3-Large
# 186            8.00         1-Small
# 187           22.00         3-Large
# 188            8.00         1-Small
# 189           20.50        2-Medium
# 190           16.50        2-Medium
# 191           20.00        2-Medium
# 192           22.00         3-Large
# 193           10.00         1-Small
# 194           17.00        2-Medium
# 195           16.00        2-Medium
# 196           27.50       4-X-large
# 197           15.25        2-Medium
# 198           25.00       4-X-large
# 199           10.00        2-Medium
# 200           22.00         3-Large
# 201           25.00         3-Large
# 202           27.00       4-X-large
# 203           24.00       4-X-large
# 204            9.00         1-Small
# 205           28.00       4-X-large
# 206           23.00         3-Large
# 207           21.00        2-Medium
# 208           16.00        2-Medium
# 209           11.00         1-Small
# 210           30.00       4-X-large
# 211           10.00         1-Small
# 212           10.50        2-Medium
# 213           19.00         3-Large
# 214           13.00        2-Medium
# 215           14.50         1-Small
# 216            9.00         1-Small
# 217           17.00        2-Medium
# 218           21.00        2-Medium
# 219            9.00         1-Small
# 220           10.00        2-Medium
# 221           26.00        2-Medium
# 222           24.50         3-Large
# 223           23.00         3-Large
# 224           16.00        2-Medium
# 225           15.50         1-Small
# 226           18.00        2-Medium
# 227           28.00       4-X-large
# 228           17.50        2-Medium
# 229           23.00         3-Large
# 230           19.00         3-Large
# 231           14.00        2-Medium
# 232           18.50        2-Medium
# 233           13.00        2-Medium
# 234           16.00        2-Medium
# 235           12.50        2-Medium
# 236            8.00        2-Medium
# 237           20.00         3-Large
# 238           25.00       4-X-large
# 239           10.00         1-Small
# 240           14.00        2-Medium
# 241           23.00       4-X-large
# 242           21.50       4-X-large
# 243           22.00         3-Large
# 244           16.00        2-Medium
# 245           22.00         3-Large
# 246           22.00        2-Medium
# 247           25.00         3-Large
# 248           18.00        2-Medium
# 249           15.00         1-Small
# 250           11.00         1-Small
# 251           23.00         3-Large
# 252           19.00        2-Medium
# 253           15.50         1-Small
# 254           22.00         3-Large
# 255           23.00         3-Large
# 256           19.00         3-Large
# 257           19.00         3-Large
# 258           21.00        2-Medium
# 259            7.00         1-Small

# %%
# Analysis of dog categories in sample set
dog_main_categories_groupby = dog_df.groupby(["Weight Category"])
dog_main_categories_groupby.count() ["Dog Name"]

# building a pie chart
dogs = ["Small", "Medium", "Large", "X-Large"]
dog_counts = [51,96,84,39]
colors = ["yellow","lightskyblue","green","red"]
explode = (0,0.1,0,0)

# Tell matplotlib to create a pie chart based upon the above data
plt.pie(dog_counts, explode=explode, labels=dogs, colors=['darkorange', 'chocolate', 'tan', 'palegoldenrod'],
        autopct="%1.1f%%", shadow=True, startangle=140)
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
plt.title("Dog Dataset Population by Category")
# Save an image of our chart and print the final product to the screen
plt.savefig("../Images/Dogs-Category-PieChart.png")
plt.show()

# %%
#find the differences between size and barking
dog_groupby = dog_df.groupby(["Weight Category","Barking"])["Barking"].count()
dog_groupby
# Out:
# Weight Category  Barking
# 1-Small          1           3
#                  2           2
#                  3          18
#                  4          18
#                  5           7
# 2-Medium         0           1
#                  1           7
#                  2           7
#                  3          48
#                  4          16
#                  5          13
# 3-Large          0           1
#                  1           8
#                  2           7
#                  3          47
#                  4          10
#                  5           5
# 4-X-large        1          11
#                  2           3
#                  3          22
#                  4           1
#                  5           1
# Name: Barking, dtype: int64

# %%
#find the differences between size and barking
dog_groupby = dog_df.groupby(["Weight Category"]).mean()["Barking"]
dog_groupby
# Out:
# Weight Category
# 1-Small      3.500000
# 2-Medium     3.195652
# 3-Large      2.923077
# 4-X-large    2.421053
# Name: Barking, dtype: float64

# %%
#graph for weight and barking - Do smaller dogs bark more?

dog_groupby.plot(kind="bar", ylabel = "Barking", title="Size vs Barking", facecolor="darkorange", alpha=0.65, rot=45, legend=True)

# Save the figure
plt.savefig("../Images/SizeVsBarkingBarChart.png", bbox_inches="tight")

plt.show()

# %%
# Size vs Life Expectancy - Is there a dog category live the longest? 

dog_life_expectancy_cat_groupby = dog_df.groupby(["Weight Category"]).mean()["Max Life Expectancy"]
dog_life_expectancy_cat_groupby

dog_life_expectancy_cat_groupby.plot(kind="bar", ylabel = "Life Expectancy", title="Size vs Life Expectancy", facecolor="darkorange", alpha=0.65, rot=45, legend=True)

# Save the figure
plt.savefig("../Images/SizeVsLifeExpectancyBarChart.png", bbox_inches="tight")

plt.show()

# %%
#y axis is percentage

dog_df.hist(column ='Max Life Expectancy', density=True, sharey=True, color = "orange", ec="black")


plt.savefig("../Images/maxlifehisogram.png", bbox_inches="tight")

plt.show()

# %%
# plot of all dogs and their life expectancy

#skewed in small dogs as there are more small and medium

box = dog_df.boxplot(by ='Weight Category', column =['Max Life Expectancy'], color="orange", grid = False, showmeans=True,
                     meanprops={"marker":"s","markerfacecolor":"orange", "markeredgecolor":"orange"})


# Save the figure

plt.savefig("../Images/Boxplot-WeightCat-LifeExpectancy.png")

plt.show()

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rank.html


# creating ranking in descending order first based on Life Expectancy 
dog_df["Life Expectancy Ranking"] = dog_df["Max Life Expectancy"].rank(method='first', ascending=False)

# dogs_with_best_life_expectancy_df = dog_df.loc[dog_df["Max Life Expectancy"] >= 18]
dogs_with_best_life_expectancy_df = dog_df.loc[dog_df["Life Expectancy Ranking"] <= 10]

dogs_with_best_life_expectancy_df["Life Expectancy Extreme"] = "Longest"
# print(dogs_with_best_life_expectancy_df)

dogs_with_best_life_expectancy_df
dog_max_life_expectancy_df = dogs_with_best_life_expectancy_df[["Dog Name", "Max Life Expectancy", "Life Expectancy Extreme"]]
dog_max_life_expectancy_df = dog_max_life_expectancy_df.set_index("Dog Name")
dog_max_life_expectancy_df
# Out:
#                     Max Life Expectancy Life Expectancy Extreme
# Dog Name
# Afghan Hound                       18.0                 Longest
# Chinese Crested                    18.0                 Longest
# Coton de Tulear                    19.0                 Longest
# Poodle (Miniature)                 18.0                 Longest
# Poodle (Standard)                  18.0                 Longest
# Poodle (Toy)                       18.0                 Longest
# Pyrenean Shepherd                  19.0                 Longest
# Rat Terrier                        18.0                 Longest
# Shih Tzu                           18.0                 Longest
# Xoloitzcuintli                     18.0                 Longest

# %%
#shorter life expectancy

# creating ranking in ascending order based on Life Expectancy field
dog_df["Life Expectancy Ranking"] = dog_df["Max Life Expectancy"].rank(method='first', ascending=True)

dogs_with_worst_life_expectancy_df = dog_df.loc[dog_df["Life Expectancy Ranking"] <= 10]
dogs_with_worst_life_expectancy_df["Life Expectancy Extreme"] = "Shortest"

dog_lowest_life_expectancy_df = dogs_with_worst_life_expectancy_df[["Dog Name", "Max Life Expectancy","Life Expectancy Extreme"]]
dog_lowest_life_expectancy_df = dog_lowest_life_expectancy_df.set_index("Dog Name")
dog_lowest_life_expectancy_df
# Out:
#                        Max Life Expectancy Life Expectancy Extreme
# Dog Name
# Bernese Mountain Dog                  10.0                Shortest
# Bullmastiff                            9.0                Shortest
# Dogue de Bordeaux                      8.0                Shortest
# Flat-Coated Retriever                 10.0                Shortest
# German Shepherd Dog                   10.0                Shortest
# Great Dane                            10.0                Shortest
# Irish Wolfhound                        8.0                Shortest
# Leonberger                             7.0                Shortest
# Neapolitan Mastiff                     9.0                Shortest
# Newfoundland                          10.0                Shortest

# %%
# Concatenate and show overall life expectancy

best_and_worst_life_expectancy_df = pd.concat([dog_max_life_expectancy_df, dog_lowest_life_expectancy_df])
best_and_worst_life_expectancy_df
# Out:
#                        Max Life Expectancy Life Expectancy Extreme
# Dog Name
# Afghan Hound                          18.0                 Longest
# Chinese Crested                       18.0                 Longest
# Coton de Tulear                       19.0                 Longest
# Poodle (Miniature)                    18.0                 Longest
# Poodle (Standard)                     18.0                 Longest
# Poodle (Toy)                          18.0                 Longest
# Pyrenean Shepherd                     19.0                 Longest
# Rat Terrier                           18.0                 Longest
# Shih Tzu                              18.0                 Longest
# Xoloitzcuintli                        18.0                 Longest
# Bernese Mountain Dog                  10.0                Shortest
# Bullmastiff                            9.0                Shortest
# Dogue de Bordeaux                      8.0                Shortest
# Flat-Coated Retriever                 10.0                Shortest
# German Shepherd Dog                   10.0                Shortest
# Great Dane                            10.0                Shortest
# Irish Wolfhound                        8.0                Shortest
# Leonberger                             7.0                Shortest
# Neapolitan Mastiff                     9.0                Shortest
# Newfoundland                          10.0                Shortest

# %%
#graph it
best_and_worst_life_expectancy_df.plot(kind="bar", ylabel="Years", 
            color="orange", 
            figsize=(15,7), alpha=0.65, rot=75, legend=True)

plt.title("Dogs with longest and shorter life expectancies")




# save figure
plt.savefig("../Images/Dogs-With-Best-and-Worst-Life-Expectancy.png", bbox_inches="tight")

plt.show()

# %%
# compare life expectancy vs dog weight
x_series = dog_df["Avg Max Weight"]
y_series = dog_df["Max Life Expectancy"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_series, y_series)
# Get regression values
regress_values = x_series * slope + intercept
# print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)
# Create Plot
plt.scatter(x_series,y_series, c = "darkorange")
plt.plot(x_series,regress_values,"k-")
# Label plot and annotate the line equation
plt.xlabel('Dog Weight')
plt.ylabel('Life Expectancy')
plt.annotate(line_eq,(115,18),fontsize=15,color="chocolate")
# Print r value
print(f"The r-value is: {rvalue}")
print(f"The r-value squared is: {rvalue**2}")

# Save the figure
plt.savefig("../Images/lifeexpectancyweightlinear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: -0.5912192292333187
# The r-value squared is: 0.3495401770152395

# %%
# compare life expectancy vs dog weight
x_series = dog_df["Avg Max Height"]
y_series = dog_df["Max Life Expectancy"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_series, y_series)
# Get regression values
regress_values = x_series * slope + intercept
# print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(line_eq)
# Create Plot
plt.scatter(x_series,y_series, c = "darkorange")
plt.plot(x_series,regress_values,"k-")
# Label plot and annotate the line equation
plt.xlabel('Dog Height')
plt.ylabel('Life Expectancy')
plt.annotate(line_eq,(10,8),fontsize=15,color="chocolate")
# Print r value
print(f"The r-value is: {rvalue}")
print(f"The r-value squared is: {rvalue**2}")

# Save the figure
plt.savefig("../Images/HeightVsLifeExpectancy.png", bbox_inches="tight")

plt.show()
# Out:
# The r-value is: -0.5022002642181645
# The r-value squared is: 0.25220510538079427

# %%
x_values = dog_df['Avg Max Height']
y_values = dog_df['Avg Max Weight']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, c = "darkorange")
plt.plot(x_values,regress_values,"k-")
plt.annotate(line_eq,(20,0),fontsize=15,color="darkorange")
plt.xlabel('Height in Inches')
plt.ylabel('Weight in Poun ds')

print(f"The r-value is: {rvalue}")
print(f"The r-value squared is: {rvalue**2}")

# Save the figure
plt.savefig("../Images/weightvsheightlinear.png", bbox_inches="tight")

plt.show()
# Out:
# The r-value is: 0.8129922272398981
# The r-value squared is: 0.66095636155249

# %%
# calculate linear regression for dogs height and weight

x_values = dog_df['Avg Max Height']**2
y_values = dog_df['Avg Max Weight']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, c = "darkorange")
plt.plot(x_values,regress_values,"k-")
plt.annotate(line_eq,(600,0),fontsize=15,color="chocolate")
plt.xlabel('Height in Inches Squared')
plt.ylabel('Weight in Pounds')
print(f"The r-value is: {rvalue}")
print(f"The r-value squared is: {rvalue**2}")

# Save the figure
plt.savefig("../Images/weightvsheightsquaredlinear.png", bbox_inches="tight")

plt.show()
# Out:
# The r-value is: 0.8329512106890161
# The r-value squared is: 0.6938077193882978
